# %%
import tensorflow as tf
import tensorflow_hub as hub
# Out:
# 2023-04-15 18:58:38.097730: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2 AVX AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
! wget --no-check-certificate -r 'https://drive.google.com/uc?export=download&id=11t-eBwdXU9EWriDhyhFBuMqHYiQ4gdae' -O dogbreed
# Out:
# WARNING: combining -O with -r or -p will mean that all downloaded content
# will be placed in the single file you specified.
#
# --2023-04-15 19:07:56--  https://drive.google.com/uc?export=download&id=11t-eBwdXU9EWriDhyhFBuMqHYiQ4gdae
# Resolving drive.google.com (drive.google.com)... 142.250.179.174
# Connecting to drive.google.com (drive.google.com)|142.250.179.174|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘dogbreed’
#
# dogbreed                [   <=>              ]   2.24K  1.07KB/s    in 2.1s
#
# 2023-04-15 19:08:15 (1.07 KB/s) - ‘dogbreed’ saved [2291]
#
# Loading robots.txt; please ignore errors.
# --2023-04-15 19:08:15--  https://drive.google.com/robots.txt
# Reusing existing connection to drive.google.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/plain]
# Saving to: ‘dogbreed’
#
# dogbreed                [ <=>                ]     570  --.-KB/s    in 0s
#
# 2023-04-15 19:08:16 (25.9 MB/s) - ‘dogbreed’ saved [570]
#
# --2023-04-15 19:08:16--  https://drive.google.com/open?id=11t-eBwdXU9EWriDhyhFBuMqHYiQ4gdae
# Reusing existing connection to drive.google.com:443.
# HTTP request sent, awaiting response... 307 Temporary Redirect
# Location: https://drive.google.com/file/d/11t-eBwdXU9EWriDhyhFBuMqHYiQ4gdae/view?usp=drive_open [following]
# --2023-04-15 19:08:16--  https://drive.google.com/file/d/11t-eBwdXU9EWriDhyhFBuMqHYiQ4gdae/view?usp=drive_open
# Reusing existing connection to drive.google.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘dogbreed’
#
# dogbreed                [ <=>                ]  74.43K   389KB/s    in 0.2s
#
# 2023-04-15 19:08:17 (389 KB/s) - ‘dogbreed’ saved [76221]
#
# FINISHED --2023-04-15 19:08:17--
# Total wall clock time: 21s
# Downloaded: 3 files, 77K in 2.3s (34.0 KB/s)

# %%
# !unzip dogbreed
# Out:
# Archive:  dogbreed
#   End-of-central-directory signature not found.  Either this file is not
#   a zipfile, or it constitutes one disk of a multi-part archive.  In the
#   latter case the central directory and zipfile comment will be found on
#   the last disk(s) of this archive.
# unzip:  cannot find zipfile directory in one of dogbreed or
#         dogbreed.zip, and cannot find dogbreed.ZIP, period.

# %%
import pandas as pd
labels_csv = pd.read_csv('labels.csv')
labels_csv.head()
# Out:
#                                  id             breed
# 0  000bec180eb18c7604dcecc8fe0dba07       boston_bull
# 1  001513dfcb2ffafc82cccf4d8bbaba97             dingo
# 2  001cdf01b096e06d78e9e5112d419397          pekinese
# 3  00214f311d5d2247d5dfe4fe24b2303d          bluetick
# 4  0021f9ceb3235effd7fcde7f7538ed62  golden_retriever

# %%
labels_csv.describe()
# Out:
#                                       id               breed
# count                              10222               10222
# unique                             10222                 120
# top     000bec180eb18c7604dcecc8fe0dba07  scottish_deerhound
# freq                                   1                 126

# %%
labels_csv['breed'].value_counts().plot.bar(figsize=(25,10))
# Out:
# <AxesSubplot:>
